# %% [markdown]
# # <p style="font-family:serif;font-size:120%;"> Capstone Project - Voice Recognition </p>

# %% [raw]
# OVERVIEW

# %% [markdown]
# <p style="font-family:serif;font-size:120%;"> <a href="https://git.generalassemb.ly/DSI-US-5/capstone/tree/master/part_02">Part 2 of Capstone</a>: https://git.generalassemb.ly/DSI-US-5/capstone/tree/master/part_02</p>

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <b><u>Objective</u></b>:
#     <br>
#     - Create a <b>Voice Recognition</b> system that can classify the voices of <b>3 people</b> at a rate better than chance.
#     <br>(I'm hoping for <b>at least 60 % accuracy</b>)
#     <br><br>
#     - I will try to optimize on <b>False Negatives</b> since, for voice based security, it would be better for the speaker to speak multiple times rather than have unwanted entities passing as the intended user.
#     <br><br>
# </p>

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <b><u>Relevancy:</u></b><br>
#     Systems like the Amazon Echo and Google Home have speaker recognition, only responding when the main user issues a voice command.<br><br> This concept can be taken further to allow for voice-based security on smart-devices and for businesses that want to allow access for their employees

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <b><u>Model</u></b>:<br>
#     - Implement using a <b>Convolutional Neural Network</b>, then use an <b>SVM</b> with the <b>features extracted from the NN</b> to classify new speakers.
#     <br>(I don't necessarily know if a CNN will work the best, that's just what they did in the blog.<br> I may change the type of NN later if I get this initial model up and running.)
#     <br><br>
# </p>

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <b><u>Data</u></b>:<br>
#     - <b>Training Data</b> will come from <b>LibriVox</b>, a source of open-domain audio books.
#     <br>I still have to process the data so I can train the model on it.
#     <br><br>
#     - <b>Testing Data</b> will come from <b>Youtube</b> or I will ask <b>classmates/friends/family</b> if I can record their voice.
#     <br><br>
#     I found the LibriVox dataset through the blog below.
#     <br>
#     The author collected the data already so I can just download the audio files and start processing them.
#     <br><br>
#     // As of right now, I still have yet to see and process the data.
#     <br>I have completed the processing pipeline. I have a little over a hundred audio books converted<br>
# </p>

# %% [markdown]
# ===============================================================================================

# %% [markdown]
# <p style="font-family:garamond;font-size:120%;">
#     <font color=#145A32  >
#     <b><u>Side Note</u></b>:<br>
#     It took me a long time to find out that "<u>speaker recognition</u>" gave better search results than "<u>voice recognition</u>"
#     </font>
#     <br><br>
# </p>

# %% [markdown]
# ===============================================================================================

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <b><u>Given extra time:</u></b><br>
#     If project is easier than it seems, I will attempt one of the following:
#     <br>
#     <b>a.</b> Use different audio processing techniques. <br>
#     <b>b.</b> Try to classify more than 3 users.<br>
#     <b>c.</b> Implement a rudimentary Google Home/Amazon Echo-like system. <br>
#     <b>d.</b> Something else here, I don't know yet <br>
#     <br>
#     If it's <u>too</u> easy, I'll do something else entirely, like (insert amazing idea here)
#     <br>
#
# </p>
#
# ---

# %% [raw]
# Speaker Recognition-Blog Related

# %% [markdown]
# <p style="font-family:serif;font-size:120%;"> This <a href="https://towardsdatascience.com/automatic-speaker-recognition-using-transfer-learning-6fab63e34e74">blog about speaker recognition</a> will be very helpful , basically outlining what I should do<br> <b> ---> https://towardsdatascience.com/automatic-speaker-recognition-using-transfer-learning-6fab63e34e74 )</b>
# <br><br>
#     Link to their <a href="https://github.com/hamzag95/voice-classification">github page</a>
#     <b>--->(https://github.com/hamzag95/voice-classification)</b>
# </p>

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     The process used to process the audio files in the blog:<br>
#     &emsp;<b>1.</b> Break each audio file down into five second segments<br><br>
#     &emsp;<b>2.</b> Convert each segment into a <b>spectrogram</b><br>
#     &emsp;&emsp;&emsp;<b>Spectrogram</b> - A visual representation of an audio file<br><br>
#     &emsp;<b>3</b>. Use these spectrograms as inputs for an Image Classifier --> CNN<br>
# </p>

# %% [markdown]
# ===============================================================================================

# %% [markdown]
# <p style="font-family:garamond;font-size:120%;">
#    <font color=#145A32  >
#        <b><u>Thoughts</u>:</b><br>
#    I was surprised by the blog's solution to this problem.<br>
#    Converting an audio file into an image seems like a pretty good solution if you don't have SME.<br>
#    But in usual audio processing techniques converting an audio file into an image is a needless step.<br>
#    You can just extract features from the audio file directly without the conversion to an image format.<br><br>
#    I will try the method described in the blog first.<br>
#    But after I may try doing usual audio processing techniques afterwards
#        </font>
# </p>

# %% [markdown]
# ===============================================================================================

# %% [raw]
# Related Videos to Subject Matter
# (for myself mainly, not necessarily useful for others reading through this notebook)

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <a href="https://www.youtube.com/watch?v=mA5nxayMfFs&t=1196s">Speaker Verification - The present and future of voiceprint based security</a><br> https://www.youtube.com/watch?v=mA5nxayMfFs&t=1196s
#     <br><br>
#     Found an <a href="https://www.youtube.com/watch?v=BttXWVbqOXs&t=954s">example</a> in MATLAB <br>https://www.youtube.com/watch?v=BttXWVbqOXs&t=954s
#     <br><br>
#     <a href="https://www.youtube.com/watch?v=yWBfBOmekjU">Microsoft Research on Low-Dimensional Audio Representation</a> <br>https://www.youtube.com/watch?v=yWBfBOmekjU
#     <br><br>
#     <a href="https://www.youtube.com/watch?v=AShHJdSIxkY">Let's Build an Audio Spectrum Analyzer in Python! (pt. 1) the waveform viewer.</a> <br>https://www.youtube.com/watch?v=AShHJdSIxkY
#     <br><br>
#     <a href="https://www.youtube.com/watch?v=JL4KJznAySE">Speech Recognition using LSTM and CTC, Mohammad Gowayyed, Tiancheng Zhao, Florian Metze</a><br>https://www.youtube.com/watch?v=JL4KJznAySE<br>CTC - Connectionist Temporal Classification
#     <br><br>
#     <a href="https://www.youtube.com/watch?v=g-sndkf7mCs">Deep Learning for Speech Recognition (Adam Coates, Baidu)</a><br>
#     https://www.youtube.com/watch?v=g-sndkf7mCs
# </p>

# %% [raw]
# Other blogs on the same subject

# %% [markdown]
# <p style="font-family:serif;font-size:120%;">
#     <a href="https://towardsdatascience.com/ok-google-how-to-do-speech-recognition-f77b5d7cbe0b">Ok Google: How to do Speech Recognition?</a><br><br>

# %% [markdown]
# <b>==============================================================================================================</b>

# %% [markdown]
# ## Look at audio archives from blog

# %% [markdown]
# #### The Data Frame below contains links (from the blog) to various archives that I will check out.

# %%
import pandas as pd

# %%
# The links to their library of audio files collected from LibriVox
# --------------------------------------------------------------------
#archives_list = ["http://www.archive.org/download//elfantasmadecantervilleyotroscuentos_1712_librivox/elfantasmadecantervilleyotroscuentos_1712_librivox_64kb_mp3.zip", "http://www.archive.org/download//billbolton_hiddendanger_1712_librivox/billbolton_hiddendanger_1712_librivox_64kb_mp3.zip", "http://www.archive.org/download//celebratedcrimes_vol_7_2_1712_librivox/celebratedcrimes_vol_7_2_1712_librivox_64kb_mp3.zip", "http://www.archive.org/download//verse_1712_librivox/verse_1712_librivox_64kb_mp3.zip", "http://www.archive.org/download/endofthemiddleage_1712_librivox/endofthemiddleage_1712_librivox_64kb_mp3.zip", "http://www.archive.org/download//marys_grammar_1711_librivox/marys_grammar_1711_librivox_64kb_mp3.zip", "http://www.archive.org/download
# Put them in a DataFrame 
# -----------------------------------------
# archives = pd.DataFrame(archives_list)

# Store in CSV
# ----------------------------------------------------------------
# archives.to_csv("archives_list.csv",columns=None, index = False)

# %%
#Read links from CSV
archives_frame = pd.read_csv("archives_list.csv",header= None,skiprows = [0])

# %%
archives_frame.shape
# Out:
# (511, 1)

# %%
archives_frame.head()
# Out:
#                                                    0
# 0  http://www.archive.org/download//elfantasmadec...
# 1  http://www.archive.org/download//billbolton_hi...
# 2  http://www.archive.org/download//celebratedcri...
# 3  http://www.archive.org/download//verse_1712_li...
# 4  http://www.archive.org/download/endofthemiddle...

# %%
archives_list[0],archives_list[-1] # First link, last link
# Out:
# ('http://www.archive.org/download//elfantasmadecantervilleyotroscuentos_1712_librivox/elfantasmadecantervilleyotroscuentos_1712_librivox_64kb_mp3.zip',
#  'http://www.archive.org/download/siege_of_corinth_0227_librivox/siege_of_corinth_0227_librivox_64kb_mp3.zip')

# %%
# Each link is a zip file to download

# I downloaded the first one and it was 147 megabytes

# I might store data on an external hard drive
# 10/11 - I have stored the data in an external hard drive

# %% [markdown]
# ======================================================================================================

# %% [markdown]
# <p style="font-family:garamond;font-size:120%;">
#    <font color=#145A32  ><b>
#        <u>Thoughts:</u><br>
#    The zip files are pretty big so I may just look at one and process it for some EDA.<br>
#    From there I'll try to streamline the process... somehow
#        <br><br>
#        <u>Update:</u> I've downloaded around 120 audio files and processed them. Processing steps below or look at notebook with code
#        </b></font>
# </p>

# %% [markdown]
# =======================================================================================================

# %% [markdown]
# ## Processing Steps (in the Process Voice Data Script Notebook)

# %% [markdown]
# <p style="font-family:garamond;font-size:120%;">
# Step to Process Data => <u>Folder in Hard Drive that data is stored in</u><br>
# 1. Download Data from archives_list -> <u>Data</u><br>
# 2. Extract Data -> <u>Data Extracted</u><br>
# 3. Combine chapters of audio book -> <u>combined</u><br>
# 4. Cut to 45 min -> <u>converted</u><br>
# 5. Convert to wav file -> <u>wav</u><br>
# 6. Take out silence -> <u>no_silence</u><br>
# 7. Split files into 5 second chunks -> <u>split</u><br>
# 8. Convert to spectrograms -> <u>spectrogram</u><br>
#     </p>

# %% [markdown]
# #### Download Data from archives_list

# %%
# Downloading script in different notebook
# I have currently download 100 of the files
# Might download some more

# "mp3wrap {a}/combined{b}.mp3 {a}/*.mp3;" 
# Looks like this line above combines the audio files in the blogs notebook
# Will have to check that out ==============HERE==========================> http://mp3wrap.sourceforge.net/

#

# %% [markdown]
# **Convert mp3 files to wav**

# %%
# Coverted mp3 files to wav 
# https://askubuntu.com/questions/919788/convert-mp3-file-to-wav-using-the-command-line
# ffmpeg -i input.mp3 output.wav

# %% [markdown]
# #### Next step would be to see how I can process the data

# %%
# This splits the Audio, but I have already done this in the other script
# This is no longer necessary, but maybe keep if ya wanna do editing later
from pydub import AudioSegment
t1 = t1 * 1000 #Works in milliseconds
t2 = t2 * 1000
newAudio = AudioSegment.from_wav("oldSong.wav")
newAudio = newAudio[t1:t2]
newAudio.export('newSong.wav', format="wav") #Exports to a wav file in the current pat

# %% [markdown]
# **Output converted wav file as spectrogram**

# %%
# Done converting files to spectrograms using sox, the command line tool
# Also check out scipy spectrograms

# %% [markdown]
# #### All the above steps have been done in the [Process Voice Data Script] notebook

# %% [markdown]
# ===================================================================================================================

# %% [markdown]
# # EDA/ Attempt at EDA

# %%
#Import Libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2

import os
import subprocess
import os.path

import time
import math


# IPython.display lets you put interactive widgets that can play audio and video, and display images
from IPython.display import Audio, Image

# Some signal processing stuff
from scipy import signal
from scipy.io import wavfile

# %%
#Function from Alex Lin - GA TA or GAHTAH .... jk
def bash(string):
    '''run a bash command and return stdout lines as a py list'''
    stdout=(subprocess.Popen(string, shell=True, stdout=subprocess.PIPE).stdout.read())
    output = str(stdout)[2:-1].split('\\n')[:-1]
    #output = str(stdout).split('\\n')[1:-1]
    #output[0] = output[0][2:]
    return output

# %% [markdown]
# ## Checking out spectrograms in SciPy

# %% [markdown]
# I already have spectrograms outputted from the sox command line tool, I'm just seeing what it looks like in SciPy

# %% [markdown]
# #### Get audio path

# %%
split = 'E:/split/'

folder_num = 0
file_num = 0

split_folders = bash('ls ' + split)
split_folders_num = split_folders[folder_num]

split_files = bash('ls '+ split + split_folders_num)
split_files_wav = split_files[file_num]

split_folders_num, split_files_wav

abs_path = split + split_folders_num + '/' + split_files_wav
abs_path
# Out:
# 'E:/split/01_mp3/01_mp3-000.wav'

# %% [markdown]
# #### Make a spectrogram

# %%
# Gets sample_rate and samples from wav file
sample_rate, samples = wavfile.read(abs_path) 
print('Audio file: ',abs_path ,'\nSample rate: ', sample_rate, ' \n# of samples: ', len(samples))
# Out:
# Audio file:  E:/split/01_mp3/01_mp3-000.wav
# Sample rate:  16000
# # of samples:  81920

# %%
# Creates and displays spectrogram
# This 
frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)

# log base e
plt.pcolormesh(times, frequencies, np.log(spectrogram))

# plt.imshow(spectrogram)
# plt.title("First audio file spectrogram")
# plt.ylabel('Frequency [Hz]')
# plt.xlabel('Time [sec]')
#plt.xticks([])
#plt.yticks([])
plt.savefig('foo.png', bbox_inches='tight')
plt.show()


# Example of first audio file
print("First audio file")
audio_path = abs_path
Audio(data = audio_path, autoplay = False, embed=True)
# Out:
# First audio file
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Try to display audio spectrogram

# %%
from tkinter import *
from PIL import ImageTk,Image

# %%
# tk = Tk()
# canvas = Canvas(tk,width = 500, height=500)
# tk.title("what")
# canvas.pack()

# ball = canvas.create_oval(10, 10, 60, 60, fill = "orange")

# for i in range(400):
#     canvas.move(ball, 1, 0)
#     tk.update()
#     time.sleep(0.01)
    
# tk.mainloop()

# %%
# Tkinter video: https://www.youtube.com/watch?v=lc8NNJgeVjI
# Find out how to play a spectogram: http://effbot.org/tkinterbook/canvas.htm

# %%
#os.system("fmedia --record --out=example3.wav --until=1")

# %%
# top = Tk()

# C = Canvas(top, bg="blue", height=250, width=300)
# filename = PhotoImage(file = "foo.png")
# background_label = Label(top, image=filename)
# background_label.place(x=0, y=0, relwidth=1, relheight=1)

# C.pack()
# top.mainloop()

# %%
# import tkinter as tk
# from PIL import Image, ImageTk

# root = tk.Tk()    
# image = Image.open("foo.png")
# photo = ImageTk.PhotoImage(image, master = root)
# label = tk.Label(root, image=photo)
# label.image = photo
# label.grid(row=2, column=0)


# #Start the program
# root.mainloop()
